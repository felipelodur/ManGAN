# %% [markdown]
# ### Dependencies

# %%
import os

# %% [markdown]
# Looking at the downloaded files:

# %%
directory = 'dataset'

stuff = []
for i in os.walk(directory):
    pass

i
# Out:
# ('dataset',
#  [],
#  ['imgs2115182-edge.jpg',
#   'imgs2115182.jpg',
#   'imgs2115183-edge.jpg',
#   'imgs2115183.jpg',
#   'imgs2115184-edge.jpg',
#   'imgs2115184.jpg',
#   'imgs2115186-edge.jpg',
#   'imgs2115186.jpg',
#   'imgs2115187-edge.jpg',
#   'imgs2115187.jpg',
#   'imgs2115190-edge.jpg',
#   'imgs2115190.jpg',
#   'imgs2115192-edge.jpg',
#   'imgs2115192.jpg',
#   'imgs2115194-edge.jpg',
#   'imgs2115194.jpg',
#   'imgs2115195-edge.jpg',
#   'imgs2115195.jpg',
#   'imgs2115199-edge.jpg',
#   'imgs2115199.jpg',
#   'imgs2115200-edge.jpg',
#   'imgs2115200.jpg',
#   'imgs2115202-edge.jpg',
#   'imgs2115202.jpg',
#   'imgs2115203-edge.jpg',
#   'imgs2115203.jpg',
#   'imgs2115205-edge.jpg',
#   'imgs2115205.jpg',
#   'imgs2115208-edge.jpg',
#   'imgs2115208.jpg',
#   'imgs2115212-edge.jpg',
#   'imgs2115212.jpg',
#   'imgs2115213-edge.jpg',
#   'imgs2115213.jpg',
#   'imgs2115214-edge.jpg',
#   'imgs2115214.jpg',
#   'imgs2115215-edge.jpg',
#   'imgs2115215.jpg',
# ...

# %% [markdown]
# A filename is like this then:

# %%
i[2][0] # check a filename
# Out:
# 'imgs2115182-edge.jpg'

# %% [markdown]
# Whjich means we can always check wheter it is an edge image by looking at specific indexes:

# %%
i[2][0][-8:-4] # this positions will tell if the image is an edge image or not.
# Out:
# 'edge'

# %% [markdown]
# And now it is pretty straightforward to separate the files:

# %%
path = 'C:\\path\\to\\dataset\\' 
edge_folder = 'edge\\'
color_folder = 'imgs\\'

for filename in i[2]:
    if(filename[-8:-4] == 'edge'):
        os.rename(path + filename, path + edge_folder + filename)
    else:
        os.rename(path + filename, path + color_folder + filename)

# %% [markdown]
# ## Done!
